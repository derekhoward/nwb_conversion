# %%
import os
import time
from pathlib import Path
import pandas as pd
import pyabf

# %%
# The following provides a dataframe for all abf files found recursively within a directory
# it outputs the filename, path to file and date created

p = Path("./data/raw/recordings")
human2019_abf_dir = Path("./data/raw/recordings/Human tissue/Human tissue-White noise_2019/")
metadata_file = "./data/raw/Metadata/Human19_metadata.csv"

def summary_df(path):
    all_files = []
    for i in path.rglob('*[!.DS_Store].abf'): # searches for all files recursively excluding those named .DS_Store
        all_files.append((i.name,  i, time.ctime(i.stat().st_ctime)))

    columns = ["file_name", "path", "created"]
    df = pd.DataFrame.from_records(all_files, columns=columns)
    df.path = df.path.astype('str')
    return df

# %% [markdown]
# # ABF file information
# Contains recordings from mouse and human and protocols include: long-square pulses, ramps, white noise...

# %%
# File info for all ABF files in data directory
df = summary_df(p)

# %%
df.shape
# Out:
# (946, 3)

# %% [markdown]
# ## Focus on human ABF recordings from 2019

# %%
human2019_file_info = summary_df(human2019_abf_dir)

# %%
human2019_file_info.shape
# Out:
# (503, 3)

# %%
human2019_file_info
# Out:
#         file_name                                               path  \
# 0    19219023.abf  data/raw/recordings/Human tissue/Human tissue-...
# 1    19219021.abf  data/raw/recordings/Human tissue/Human tissue-...
# 2    19219005.abf  data/raw/recordings/Human tissue/Human tissue-...
# 3    19219004.abf  data/raw/recordings/Human tissue/Human tissue-...
# 4    19219016.abf  data/raw/recordings/Human tissue/Human tissue-...
# ..            ...                                                ...
# 498  19o10047.abf  data/raw/recordings/Human tissue/Human tissue-...
# 499  19o10043.abf  data/raw/recordings/Human tissue/Human tissue-...
# 500  19o10048.abf  data/raw/recordings/Human tissue/Human tissue-...
# 501  19o10051.abf  data/raw/recordings/Human tissue/Human tissue-...
# 502  19o10050.abf  data/raw/recordings/Human tissue/Human tissue-...
#
#                       created
# 0    Fri Apr  9 16:26:54 2021
# 1    Fri Apr  9 16:26:54 2021
# 2    Fri Apr  9 16:26:54 2021
# 3    Fri Apr  9 16:26:54 2021
# 4    Fri Apr  9 16:26:54 2021
# ..                        ...
# 498  Fri Apr  9 16:26:54 2021
# 499  Fri Apr  9 16:26:54 2021
# 500  Fri Apr  9 16:26:54 2021
# 501  Fri Apr  9 16:26:54 2021
# 502  Fri Apr  9 16:26:54 2021
#
# [503 rows x 3 columns]

# %%
human19_meta_df = pd.read_csv(metadata_file)
human19_meta_df['file_name'] = human19_meta_df.loc[:, 'ABF File'] + '.abf'

# %%
human19_meta_df.shape
# Out:
# (536, 12)

# %%
human19_meta_df.head()
# Out:
#    Unnamed: 0         ABF File Data Type    Exp. Date Cell # Cell Layer  \
# 0           1  2019_11_04_0069     Human  Nov_04_2019     C1        L3C
# 1           2  2019_11_04_0069     Human  Nov_04_2019     C1        L3C
# 2           3  2019_11_04_0073     Human  Nov_04_2019     C1        L3C
# 3           4  2019_11_04_0073     Human  Nov_04_2019     C1        L3C
# 4           5  2019_11_04_0041     Human  Nov_04_2019     C1        L3C
#
#      Stim Type Threshold   DC         ZD Hold            file_name
# 0  White noise       n.a  n.a   After ZD  n.a  2019_11_04_0069.abf
# 1  White noise       n.a  n.a   After ZD  n.a  2019_11_04_0069.abf
# 2  White noise       n.a  n.a   After ZD  n.a  2019_11_04_0073.abf
# 3  White noise       n.a  n.a   After ZD  n.a  2019_11_04_0073.abf
# 4  White noise       n.a  n.a  Before ZD  n.a  2019_11_04_0041.abf

# %%
# there are 42 duplicates in the metadata
human19_meta_df[human19_meta_df.duplicated(subset='ABF File', keep=False)].shape
# Out:
# (42, 12)

# %%
# add new column for duplicated files
human19_meta_df['is_duplicate'] = human19_meta_df.duplicated(subset='ABF File', keep=False)

# %% [markdown]
# ## Focus on "intrinsic properties" experiments with long-square pulses

# %%
ip_meta_df = human19_meta_df[human19_meta_df['Stim Type'] == 'Intrinsic Properties']

# %%
ip_meta_df
# Out:
#      Unnamed: 0         ABF File Data Type    Exp. Date Cell # Cell Layer  \
# 213         214  2019_11_04_0095     Human  Nov_04_2019     C2        L3C
# 214         215  2019_11_04_0096     Human  Nov_04_2019     C2        L3C
# 215         216  2019_11_04_0097     Human  Nov_04_2019     C2        L3C
# 216         217  2019_11_04_0098     Human  Nov_04_2019     C2        L3C
# 217         218  2019_11_04_0099     Human  Nov_04_2019     C2        L3C
# ..          ...              ...       ...          ...    ...        ...
# 513         514  2019_09_03_0085     Human  Sep_03-2019     C9         L2
# 514         515  2019_09_03_0086     Human  Sep_03-2019     C9         L2
# 515         516  2019_09_03_0087     Human  Sep_03-2019     C9         L2
# 516         517  2019_09_03_0088     Human  Sep_03-2019     C9         L2
# 517         518  2019_09_03_0089     Human  Sep_03-2019     C9         L2
#
#                 Stim Type Threshold   DC   ZD Hold            file_name  \
# 213  Intrinsic Properties       n.a  n.a   ZD  n.a  2019_11_04_0095.abf
# 214  Intrinsic Properties       n.a  n.a   ZD  n.a  2019_11_04_0096.abf
# 215  Intrinsic Properties       n.a  n.a   ZD  n.a  2019_11_04_0097.abf
# 216  Intrinsic Properties       n.a  n.a   ZD  n.a  2019_11_04_0098.abf
# 217  Intrinsic Properties       n.a  n.a   ZD  n.a  2019_11_04_0099.abf
# ..                    ...       ...  ...  ...  ...                  ...
# 513  Intrinsic Properties       n.a  n.a  n.a  n.a  2019_09_03_0085.abf
# 514  Intrinsic Properties       n.a  n.a  n.a  n.a  2019_09_03_0086.abf
# 515  Intrinsic Properties       n.a  n.a  n.a  n.a  2019_09_03_0087.abf
# 516  Intrinsic Properties       n.a  n.a  n.a  n.a  2019_09_03_0088.abf
# 517  Intrinsic Properties       n.a  n.a  n.a  n.a  2019_09_03_0089.abf
#
#      is_duplicate
# 213         False
# 214         False
# 215         False
# 216         False
# 217         False
# ..            ...
# 513         False
# 514         False
# 515         False
# 516         False
# 517         False
#
# [221 rows x 13 columns]

# %%
ip_meta_df[ip_meta_df.duplicated(subset='ABF File', keep=False)]
# Out:
#      Unnamed: 0  ABF File Data Type      Exp. Date Cell # Cell Layer  \
# 351         352  19129000     Human    Jan_29_2019     C1         L5
# 352         353  19129002     Human    Jan_29_2019     C1         L5
# 353         354  19129003     Human    Jan_29_2019     C1         L5
# 354         355  19129004     Human    Jan_29_2019     C1         L5
# 355         356  19129010     Human    Jan_29_2019     C1         L5
# 378         379  19319019     Human  March_19_2019     C4         L5
# 379         380  19319020     Human  March_19_2019     C4         L5
# 380         381  19319019     Human  March_19_2019     C6         L5
# 381         382  19319020     Human  March_19_2019     C6         L5
# 480         481  19129000     Human    Sep_03-2019     C1         L2
# 481         482  19129002     Human    Sep_03-2019     C1         L2
# 482         483  19129003     Human    Sep_03-2019     C1         L2
# 483         484  19129004     Human    Sep_03-2019     C1         L2
# 484         485  19129010     Human    Sep_03-2019     C1         L2
#
#                 Stim Type Threshold   DC   ZD Hold     file_name  is_duplicate
# 351  Intrinsic Properties       n.a  n.a  n.a  n.a  19129000.abf          True
# 352  Intrinsic Properties       n.a  n.a  n.a  n.a  19129002.abf          True
# 353  Intrinsic Properties       n.a  n.a  n.a  n.a  19129003.abf          True
# 354  Intrinsic Properties       n.a  n.a  n.a  n.a  19129004.abf          True
# 355  Intrinsic Properties       n.a  n.a  n.a  n.a  19129010.abf          True
# 378  Intrinsic Properties       n.a  n.a  n.a  n.a  19319019.abf          True
# 379  Intrinsic Properties       n.a  n.a  n.a  n.a  19319020.abf          True
# 380  Intrinsic Properties       n.a  n.a  n.a  n.a  19319019.abf          True
# 381  Intrinsic Properties       n.a  n.a  n.a  n.a  19319020.abf          True
# 480  Intrinsic Properties       n.a  n.a  n.a  n.a  19129000.abf          True
# 481  Intrinsic Properties       n.a  n.a  n.a  n.a  19129002.abf          True
# 482  Intrinsic Properties       n.a  n.a  n.a  n.a  19129003.abf          True
# 483  Intrinsic Properties       n.a  n.a  n.a  n.a  19129004.abf          True
# 484  Intrinsic Properties       n.a  n.a  n.a  n.a  19129010.abf          True

# %% [markdown]
# ### Select file information for long-squares using metadata from above

# %%
human2019_file_info.head()
# Out:
#       file_name                                               path  \
# 0  19219023.abf  data/raw/recordings/Human tissue/Human tissue-...
# 1  19219021.abf  data/raw/recordings/Human tissue/Human tissue-...
# 2  19219005.abf  data/raw/recordings/Human tissue/Human tissue-...
# 3  19219004.abf  data/raw/recordings/Human tissue/Human tissue-...
# 4  19219016.abf  data/raw/recordings/Human tissue/Human tissue-...
#
#                     created
# 0  Fri Apr  9 16:26:54 2021
# 1  Fri Apr  9 16:26:54 2021
# 2  Fri Apr  9 16:26:54 2021
# 3  Fri Apr  9 16:26:54 2021
# 4  Fri Apr  9 16:26:54 2021

# %%
# select file_info with files of interest (for long-square pulses)
long_squares2019 = human2019_file_info[human2019_file_info.file_name.isin(ip_meta_df.file_name)]

# %%
long_squares2019.shape
# Out:
# (221, 3)

# %% [markdown]
# ### Identify ABF version of files of interest

# %%
version_info = []

for i, abf_info in long_squares2019.iterrows():
    abf = pyabf.ABF(abf_info.path)
    abf_version = abf.abfVersionString
    version_info.append((abf_info.file_name, abf_version, abf_info.path))

# %%
version_df = pd.DataFrame(version_info, columns=['file_name', 'version', 'path'])

# %%
version_df[version_df.duplicated(subset='file_name', keep=False)]
# Out:
#         file_name  version                                               path
# 49   19129003.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 50   19129002.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 51   19129000.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 52   19129004.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 53   19129010.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 68   19319019.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 69   19319020.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 71   19319019.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 72   19319020.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 181  19129003.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 182  19129002.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 183  19129000.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 184  19129004.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...
# 185  19129010.abf  1.8.3.0  data/raw/recordings/Human tissue/Human tissue-...

# %%
long_squares2019 = long_squares2019.merge(version_df)

# %%
# add a column for files I believe should be dropped from analysis
# this also allows for merging back to original metadata without creating extra rows when merging on 'file_name'
long_squares2019['to_drop'] = long_squares2019.duplicated('file_name', keep='last')

# %%
ip_meta_df[ip_meta_df.is_duplicate]
# Out:
#      Unnamed: 0  ABF File Data Type      Exp. Date Cell # Cell Layer  \
# 351         352  19129000     Human    Jan_29_2019     C1         L5
# 352         353  19129002     Human    Jan_29_2019     C1         L5
# 353         354  19129003     Human    Jan_29_2019     C1         L5
# 354         355  19129004     Human    Jan_29_2019     C1         L5
# 355         356  19129010     Human    Jan_29_2019     C1         L5
# 378         379  19319019     Human  March_19_2019     C4         L5
# 379         380  19319020     Human  March_19_2019     C4         L5
# 380         381  19319019     Human  March_19_2019     C6         L5
# 381         382  19319020     Human  March_19_2019     C6         L5
# 480         481  19129000     Human    Sep_03-2019     C1         L2
# 481         482  19129002     Human    Sep_03-2019     C1         L2
# 482         483  19129003     Human    Sep_03-2019     C1         L2
# 483         484  19129004     Human    Sep_03-2019     C1         L2
# 484         485  19129010     Human    Sep_03-2019     C1         L2
#
#                 Stim Type Threshold   DC   ZD Hold     file_name  is_duplicate
# 351  Intrinsic Properties       n.a  n.a  n.a  n.a  19129000.abf          True
# 352  Intrinsic Properties       n.a  n.a  n.a  n.a  19129002.abf          True
# 353  Intrinsic Properties       n.a  n.a  n.a  n.a  19129003.abf          True
# 354  Intrinsic Properties       n.a  n.a  n.a  n.a  19129004.abf          True
# 355  Intrinsic Properties       n.a  n.a  n.a  n.a  19129010.abf          True
# 378  Intrinsic Properties       n.a  n.a  n.a  n.a  19319019.abf          True
# 379  Intrinsic Properties       n.a  n.a  n.a  n.a  19319020.abf          True
# 380  Intrinsic Properties       n.a  n.a  n.a  n.a  19319019.abf          True
# 381  Intrinsic Properties       n.a  n.a  n.a  n.a  19319020.abf          True
# 480  Intrinsic Properties       n.a  n.a  n.a  n.a  19129000.abf          True
# 481  Intrinsic Properties       n.a  n.a  n.a  n.a  19129002.abf          True
# 482  Intrinsic Properties       n.a  n.a  n.a  n.a  19129003.abf          True
# 483  Intrinsic Properties       n.a  n.a  n.a  n.a  19129004.abf          True
# 484  Intrinsic Properties       n.a  n.a  n.a  n.a  19129010.abf          True

# %%
# has half as many rows to drop as are listed as duplicate
long_squares2019[long_squares2019.to_drop]
# Out:
#        file_name                                               path  \
# 49  19129003.abf  data/raw/recordings/Human tissue/Human tissue-...
# 50  19129002.abf  data/raw/recordings/Human tissue/Human tissue-...
# 51  19129000.abf  data/raw/recordings/Human tissue/Human tissue-...
# 52  19129004.abf  data/raw/recordings/Human tissue/Human tissue-...
# 53  19129010.abf  data/raw/recordings/Human tissue/Human tissue-...
# 68  19319019.abf  data/raw/recordings/Human tissue/Human tissue-...
# 69  19319020.abf  data/raw/recordings/Human tissue/Human tissue-...
#
#                      created  version  to_drop
# 49  Fri Apr  9 16:26:54 2021  1.8.3.0     True
# 50  Fri Apr  9 16:26:54 2021  1.8.3.0     True
# 51  Fri Apr  9 16:26:54 2021  1.8.3.0     True
# 52  Fri Apr  9 16:26:54 2021  1.8.3.0     True
# 53  Fri Apr  9 16:26:54 2021  1.8.3.0     True
# 68  Fri Apr  9 16:26:54 2021  1.8.3.0     True
# 69  Fri Apr  9 16:26:54 2021  1.8.3.0     True

# %%
updated_meta = ip_meta_df.merge(long_squares2019.drop('created', axis=1), on='file_name')

# %%
meta_output_path = Path('./data/processed/meta')
meta_output_path.mkdir(parents=True, exist_ok=True)
updated_meta.to_csv(meta_output_path/'human_2019_intrinsic_properties_meta.csv', index=None)

# %%
updated_meta = updated_meta[updated_meta.to_drop == False]

# %%
updated_meta.version.value_counts()
# Out:
# 2.6.0.0    116
# 1.8.3.0    105
# Name: version, dtype: int64

# %%
#group_1 = IP_df[(IP_df['Unnamed: 0'] >= 312) & (IP_df['Unnamed: 0'] <= 414)]

# check to see whether version is same as maggie found
test = updated_meta[(updated_meta['Unnamed: 0'] >= 312) & (updated_meta['Unnamed: 0'] <= 414)]

# %%
test.version.value_counts()
# Out:
# 1.8.3.0    100
# Name: version, dtype: int64
