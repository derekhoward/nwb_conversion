# %%
import os
import time
import datetime
from pathlib import Path
import numpy as np
import pandas as pd
import pyabf
import utils

# %load_ext autoreload
# %autoreload 2

# %%
human18_meta = pd.read_csv('./data/raw/Metadata/Human18_Metadatav2.csv')
human18_meta.drop('Unnamed: 0', axis=1, inplace=True)

# %%
human18_meta.shape
# Out:
# (139, 18)

# %%
human18_meta.head()
# Out:
#    ABF File Data Type      Exp. Date Case # Cell # Cell Layer Stim Type  \
# 0  18320001     Human  March_20_2018  First     C1        L23    Firing
# 1  18320005     Human  March_20_2018  First     C1        L23    Firing
# 2  18320015     Human  March_20_2018  First     C2        L23    Firing
# 3  18320019     Human  March_20_2018  First     C3        L23    Firing
# 4  18320021     Human  March_20_2018  First     C3        L23    Firing
#
#   Threshold Gain Value   ZD Hold  Unnamed: 12  Gain  Offset Response Channel  \
# 0       n.a        n.a  n.a  n.a          NaN   1.0   -20.0       Iclamp(mV)
# 1       n.a        n.a  n.a  n.a          NaN   1.0   -20.0       Iclamp(mV)
# 2       n.a        n.a  n.a  n.a          NaN   1.0   -20.0       Iclamp(mV)
# 3       n.a        n.a  n.a  n.a          NaN   1.0   -27.0       Iclamp(mV)
# 4       n.a        n.a  n.a  n.a          NaN   1.0   -27.0       Iclamp(mV)
#
#   Command Channel   RMP Stimulus type
# 0  Current_in(pA) -70.0          Ramp
# 1  Current_in(pA) -70.5   Long_Square
# 2  Current_in(pA) -68.1   Long_Square
# 3  Current_in(pA) -71.3          Ramp
# 4  Current_in(pA) -71.3   Long_Square

# %% [markdown]
# ## Identify files to be converted
# - ABF files from human2018
# - need metadata to determine which files are testing intrinsic properties
# - extract ABF version info, time of creation and comments from the ABF file

# %%
human2018_abf_dir = Path("./data/raw/recordings/Human tissue/Human tissue-White noise_2018/")
human2018_file_info = utils.summary_df(human2018_abf_dir)

# %%
# %%time
def parse_timestamp(abf_path):
    abf = pyabf.ABF(abf_path)
    return datetime.datetime.strptime(abf.abfDateTimeString, "%Y-%m-%dT%H:%M:%S.%f")

def extract_abf_version(abf_path):
    abf = pyabf.ABF(abf_path)
    return abf.abfVersionString

def extract_abf_comments(abf_path):
    abf = pyabf.ABF(abf_path)
    return abf.tagComments

human2018_file_info['timestamp'] = human2018_file_info.path.apply(parse_timestamp)
human2018_file_info['abf_version'] = human2018_file_info.path.apply(extract_abf_version)
human2018_file_info['abf_comments'] = human2018_file_info.path.apply(extract_abf_comments)

# add this column to merge with provided metadata
human2018_file_info['file_id'] = human2018_file_info.file_name.apply(lambda x: Path(x).stem)
# Out:
# CPU times: user 2.43 s, sys: 900 ms, total: 3.33 s
# Wall time: 3.57 s

# %%
human2018_file_info.shape
# Out:
# (174, 6)

# %%
human2018_file_info.file_name.nunique()
# Out:
# 162

# %%
human2018_file_info.head()
# Out:
#       file_name                                               path  \
# 0  18417020.abf  data/raw/recordings/Human tissue/Human tissue-...
# 1  18417023.abf  data/raw/recordings/Human tissue/Human tissue-...
# 2  18417026.abf  data/raw/recordings/Human tissue/Human tissue-...
# 3  18417030.abf  data/raw/recordings/Human tissue/Human tissue-...
# 4  18417025.abf  data/raw/recordings/Human tissue/Human tissue-...
#
#                 timestamp abf_version  \
# 0 2018-04-17 15:04:31.906     1.8.3.0
# 1 2018-04-17 15:07:01.500     1.8.3.0
# 2 2018-04-17 15:24:09.921     1.8.3.0
# 3 2018-04-17 15:42:51.375     1.8.3.0
# 4 2018-04-17 15:12:11.625     1.8.3.0
#
#                                         abf_comments   file_id
# 0  [Cell 3,  RMP -64.7 L2/3;, Cell 3,  RMP -64.7 ...  18417020
# 1         [Cell 3,  RMP -64.7 L2/3; offset -17.5 mv]  18417023
# 2  [Cell 3,  RMP -64.7 L2/3; offset -17.5 mv, Gai...  18417026
# 3  [Cell 3,  RMP -64.7 L2/3; offset -17.5 mv, Gai...  18417030
# 4  [Cell 3,  RMP -64.7 L2/3; offset -17.5 mv, Gai...  18417025

# %%
human2018_file_info.abf_version.value_counts()
# Out:
# 1.8.3.0    174
# Name: abf_version, dtype: int64

# %% [markdown]
# ## identify issues with duplicates

# %%
human2018_file_info[human2018_file_info.duplicated(subset=['file_id', 'timestamp'], keep=False)]
# Out:
#        file_name                                               path  \
# 81  18129016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 82  18129015.abf  data/raw/recordings/Human tissue/Human tissue-...
# 83  18129016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 84  18129015.abf  data/raw/recordings/Human tissue/Human tissue-...
#
#                  timestamp abf_version  \
# 81 2018-01-29 16:08:33.000     1.8.3.0
# 82 2018-01-29 16:01:20.750     1.8.3.0
# 83 2018-01-29 16:08:33.000     1.8.3.0
# 84 2018-01-29 16:01:20.750     1.8.3.0
#
#                                       abf_comments   file_id
# 81  [C4,  L5, RMP: -69.4 mv, Gain 20, Dc 50, 1-30]  18129016
# 82  [C4,  L5, RMP: -69.4 mv, Gain 20, Dc 25, 1-30]  18129015
# 83  [C4,  L5, RMP: -69.4 mv, Gain 20, Dc 50, 1-30]  18129016
# 84  [C4,  L5, RMP: -69.4 mv, Gain 20, Dc 25, 1-30]  18129015

# %%
human2018_file_info[human2018_file_info.duplicated(subset='file_id', keep=False)]
# Out:
#         file_name                                               path  \
# 81   18129016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 82   18129015.abf  data/raw/recordings/Human tissue/Human tissue-...
# 83   18129016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 84   18129015.abf  data/raw/recordings/Human tissue/Human tissue-...
# 101  18320002.abf  data/raw/recordings/Human tissue/Human tissue-...
# 103  18320001.abf  data/raw/recordings/Human tissue/Human tissue-...
# 104  18320006.abf  data/raw/recordings/Human tissue/Human tissue-...
# 105  18320007.abf  data/raw/recordings/Human tissue/Human tissue-...
# 109  18320016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 110  18320019.abf  data/raw/recordings/Human tissue/Human tissue-...
# 111  18320020.abf  data/raw/recordings/Human tissue/Human tissue-...
# 112  18320014.abf  data/raw/recordings/Human tissue/Human tissue-...
# 114  18320015.abf  data/raw/recordings/Human tissue/Human tissue-...
# 123  18320002.abf  data/raw/recordings/Human tissue/Human tissue-...
# 124  18320001.abf  data/raw/recordings/Human tissue/Human tissue-...
# 126  18320006.abf  data/raw/recordings/Human tissue/Human tissue-...
# 127  18320007.abf  data/raw/recordings/Human tissue/Human tissue-...
# 130  18320020.abf  data/raw/recordings/Human tissue/Human tissue-...
# 131  18320019.abf  data/raw/recordings/Human tissue/Human tissue-...
# 133  18320014.abf  data/raw/recordings/Human tissue/Human tissue-...
# 134  18320015.abf  data/raw/recordings/Human tissue/Human tissue-...
# 137  18320016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 149  18201028.abf  data/raw/recordings/Human tissue/Human tissue-...
# 160  18201028.abf  data/raw/recordings/Human tissue/Human tissue-...
#
#                   timestamp abf_version  \
# 81  2018-01-29 16:08:33.000     1.8.3.0
# 82  2018-01-29 16:01:20.750     1.8.3.0
# 83  2018-01-29 16:08:33.000     1.8.3.0
# 84  2018-01-29 16:01:20.750     1.8.3.0
# 101 2018-03-20 18:12:52.812     1.8.3.0
# 103 2018-03-20 18:12:52.812     1.8.3.0
# 104 2018-03-20 18:22:37.390     1.8.3.0
# 105 2018-03-20 18:26:28.390     1.8.3.0
# 109 2018-03-20 19:35:05.781     1.8.3.0
# 110 2018-03-20 19:36:50.875     1.8.3.0
# 111 2018-03-20 19:40:22.000     1.8.3.0
# 112 2018-03-20 19:21:24.968     1.8.3.0
# 114 2018-03-20 19:24:55.578     1.8.3.0
# 123 2018-03-20 13:41:32.343     1.8.3.0
# 124 2018-03-20 13:39:05.328     1.8.3.0
# 126 2018-03-20 13:47:19.468     1.8.3.0
# 127 2018-03-20 13:58:41.125     1.8.3.0
# 130 2018-03-20 16:51:16.156     1.8.3.0
# 131 2018-03-20 16:48:53.781     1.8.3.0
# 133 2018-03-20 15:06:08.765     1.8.3.0
# 134 2018-03-20 15:06:08.765     1.8.3.0
# 137 2018-03-20 15:09:14.406     1.8.3.0
# 149 2018-02-01 16:11:35.984     1.8.3.0
# 160 2018-02-01 15:54:20.796     1.8.3.0
#
#                                           abf_comments   file_id
# 81      [C4,  L5, RMP: -69.4 mv, Gain 20, Dc 50, 1-30]  18129016
# 82      [C4,  L5, RMP: -69.4 mv, Gain 20, Dc 25, 1-30]  18129015
# 83      [C4,  L5, RMP: -69.4 mv, Gain 20, Dc 50, 1-30]  18129016
# 84      [C4,  L5, RMP: -69.4 mv, Gain 20, Dc 25, 1-30]  18129015
# 101                            [C1; L2/3; RMP --61.4;]  18320002
# 103                            [C1; L2/3; RMP --61.4;]  18320001
# 104  [C1; L2/3; RMP --61.4; offset -20; Gain 20; DC...  18320006
# 105  [C1; L2/3; RMP --61.4; offset -20; Gain 20; DC...  18320007
# 109                             [C3; L2/3; RMP -66.2;]  18320016
# 110                             [C3; L2/3; RMP -66.2;]  18320019
# 111              [C3; L2/3; RMP -66.2; Gain 40; Dc 75]  18320020
# 112                              [C2; L2/3; RMP -65.2]  18320014
# 114             [C2; L2/3; RMP -65.2; Gain 20; DC 175]  18320015
# 123  [C1; L2/3; RMP -70.5; Offset 20 mv; Short puls...  18320002
# 124  [C1; L2/3; RMP -70.5; Offset 20 mv; RAMP 25pA/...  18320001
# 126  [C1; L2/3; RMP -70.5; Offset 20 mv; Gain 20; D...  18320006
# 127                                                 []  18320007
# 130              [C3; L2/3; RMP -71.3; offset -27 mv;]  18320020
# 131              [C3; L2/3; RMP -71.3; offset -27 mv;]  18320019
# 133               [C2; L2/3; RMP -68.1; offset -20 mv]  18320014
# 134               [C2; L2/3; RMP -68.1; offset -20 mv]  18320015
# 137  [C2; L2/3; RMP -68.1; offset -20 mv; Gain 20; ...  18320016
# 149                       [C5, RMP -66.9 mv, layer 5,]  18201028
# 160  [C4, RMP -64.8 mv, layer 5,Gain 20, DC 25, C4,...  18201028

# %% [markdown]
# ## Merge metadata with extracted information about ABF files

# %%
merged_meta = human18_meta.merge(human2018_file_info, left_on='ABF File', right_on='file_id' , how='left')

# %%
# we are left with 36 files to convert
merged_meta.abf_version.value_counts()
# Out:
# 1.8.3.0    158
# Name: abf_version, dtype: int64

# %%
merged_meta['ABF File'].nunique()
# Out:
# 131

# %% [markdown]
# ## Convert

# %%
output_dir = Path("data/processed/recordings/human2018/")
output_dir.mkdir(exist_ok=True, parents=True)

# %%
to_convert = merged_meta[merged_meta['Stim Type'] == 'Firing'].drop_duplicates('file_id')

# %%
def get_stim_chan(abf_path):
    abf = pyabf.ABF(abf_path)
    return abf.dacNames[1]

def get_resp_chan(abf_path):
    abf = pyabf.ABF(abf_path)
    return abf.adcNames[0]

# %%
to_convert['stim_chan'] = to_convert.path.apply(get_stim_chan)
to_convert['resp_chan'] = to_convert.path.apply(get_resp_chan)

# %%
to_convert.abf_version.value_counts()
# Out:
# 1.8.3.0    41
# Name: abf_version, dtype: int64

# %%
from x_to_nwb import ABF1Converter_meta2

def generate_subject_meta(row):
    meta = {
    'Subject': {
        'age': None,
        'description': f'{row.abf_comments}',
        'species': 'Homo sapiens',
        'subject_id': f'Donor_{row.file_id}'}
    }
    return meta


def convert_abfv1_row(row):
    abf = pyabf.ABF(row.path)
    file_stem = row.file_id
    output_path = output_dir / f'{file_stem}.nwb'
    meta = generate_subject_meta(row)

    nwb = ABF1Converter_meta2.ABF1Converter(row.path,
                                      str(output_path), 
                                      acquisitionChannelName=row.resp_chan,
                                      stimulusChannelName=row.stim_chan,
                                      responseOffset=row.Offset,
                                      metadata=meta,
                                      responseGain=float(row.Gain) * 1000)
    
    nwb.convert()

    print(f"NWB Conversion complete for {output_path}")

# %%
successes = []
errors = []

for i, row in to_convert.iterrows():
    if row.abf_version == '2.6.0.0':
        try:
            convert_abfv2_row(row)
            successes.append((row.file_id, row.path))
        except (ValueError, IndexError, TypeError, KeyError) as e:
            print('**'*50)
            print(f'Error: {e} \n {row.path} \n')
            errors.append((e, row.file_id, row.path))
    
    elif row.abf_version == '1.8.3.0':
        try:
            convert_abfv1_row(row)
            successes.append((row.file_id, row.path))
        except (ValueError, IndexError, TypeError, KeyError, AttributeError) as e:
            print('**'*50)
            print(f'Error: {e} \n {row.path} \n')
            errors.append((e, row.file_id, row.path))
# Out:
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/Second case/C1_L23/firing/18320001.abf
# ****************************************************************************************************
# Error: 'NoneType' object is not callable
#  data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/Second case/C1_L23/firing/18320001.abf
#
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/First case/C1_L23/Firing/18320005.abf
# /Users/derek_howard/miniconda3/envs/nwbephystest/lib/python3.8/site-packages/pynwb/file.py:753: UserWarning: Date is missing timezone information. Updating to local timezone.
#   warn("Date is missing timezone information. Updating to local timezone.")
# Successfully converted to data/processed/recordings/human2018/18320005.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18320005.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/Second case/C2_L23/Gain 20/18320015.abf
# ****************************************************************************************************
# Error: 'ABF' object has no attribute '_stringsIndexed'
#  data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/Second case/C2_L23/Gain 20/18320015.abf
#
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/Second case/C3_L23/Firing/18320019.abf
# Successfully converted to data/processed/recordings/human2018/18320019.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18320019.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/First case/C3_L23/Firing/18320021.abf
# Successfully converted to data/processed/recordings/human2018/18320021.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18320021.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/Second case/C1_L23/firing/18320000.abf
# Successfully converted to data/processed/recordings/human2018/18320000.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18320000.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/Second case/C2_L23/Firing/18320012.abf
# Successfully converted to data/processed/recordings/human2018/18320012.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18320012.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_20_2018/Second case/
nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18329043.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/March_29_2018/C9.2_L23/Firing/18329044.abf
# Successfully converted to data/processed/recordings/human2018/18329044.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18329044.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/October_ 22_2018/C1_L23/Firing/18o22001.abf
# Successfully converted to data/processed/recordings/human2018/18o22001.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18o22001.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/October_ 22_2018/C2_L23/Firing/18o22010.abf
# Successfully converted to data/processed/recordings/human2018/18o22010.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18o22010.nwb
# data/raw/recordings/Human tissue/Human tissue-White noise_2018/October_ 22_2018/C3_L23/Firing/18o22020.abf
# Successfully converted to data/processed/recordings/human2018/18o22020.nwb.
# NWB Conversion complete for data/processed/recordings/human2018/18o22020.nwb

# %%
# !dandi validate "data/processed/recordings/human2018/newtest/"
# Out:
# 2021-07-28 15:30:22,517 [ WARNING] A newer version (0.25.0) of dandi/dandi-cli is available. You are using 0.23.2
# Usage: dandi validate [OPTIONS] [PATHS]...
# Try 'dandi validate --help' for help.
#
# Error: Invalid value for '[PATHS]...': Path 'data/processed/recordings/human2018/newtest/' does not exist.

# %% [markdown]
# ## Extract stimulus info to later merge with metadata

# %%
converted_nwb_paths = list(Path('data/processed/recordings/human2018/').glob('*.nwb'))

# %%
converted_nwb_file_ids = [x.stem for x in converted_nwb_paths]

# %%
converted_nwb_file_ids
# Out:
# ['18329051',
#  '18329044',
#  '18329050',
#  '18o22020',
#  '18129004',
#  '18329043',
#  '18320016',
#  '18220002',
#  '18329033',
#  '18329031',
#  '18320014',
#  '18320000',
#  '18426010',
#  '18426000',
#  '18320005',
#  '18426017',
#  '18220007',
#  '18320012',
#  '18426016',
#  '18329013',
#  '18201005',
#  '18201011',
#  '18220008',
#  '18320021',
#  '18201004',
#  '18426009',
#  '18201028',
#  '18320019',
#  '18220019',
#  '18320031',
#  '18320030',
#  '18329014',
#  '18320024',
#  '18220018',
#  '18201029',
#  '18o22001',
#  '18129009',
#  '18329062',
#  '18o22010']

# %%
to_extract_stim_info = human2018_file_info[human2018_file_info.file_id.isin(converted_nwb_file_ids)]

# %%
# parse relevant info related to stimulus, including duration, and amplitudes
def get_stim_info(abf_path, stim_channel_num = 1, stim_gain = 1, stim_name = 'sweepC'):
    abf = pyabf.ABF(abf_path)
    num_sweeps = abf.sweepCount
    stim_amps = np.zeros(num_sweeps) 
    stim_start_time = None
    stim_end_time = None
    sampling_rate = int(round(1/(abf.sweepX[2] - abf.sweepX[1]))) # manually calculate the sampling rate

    for i in range(0, num_sweeps):
        abf.setSweep(i, channel=stim_channel_num)
        sampling_rate = abf.dataRate
        if stim_name == 'sweepY':
            stim_vec = np.round(abf.sweepY * stim_gain)
        else:
            stim_vec = np.round(abf.sweepC * stim_gain)
        stim_amp = stim_vec[5000]

        stim_amps[i] = round(stim_amp)
        non_zero_inds = np.where(stim_vec == stim_amp)
        stim_duration = np.shape(non_zero_inds)[1] * 1/sampling_rate
        if stim_duration == 0:
            continue
        stim_start_ind = non_zero_inds[0][0]
        stim_end_ind = non_zero_inds[0][-1]
        
        stim_start_time = abf.sweepX[stim_start_ind]
        stim_end_time = abf.sweepX[stim_end_ind]

    ret_dict = {'stim_amp_vec' : stim_amps, 'stim_duration' : stim_duration, 
                'stim_start_time' : stim_start_time, 'stim_end_time' : stim_end_time, 'num_sweeps' : num_sweeps,
               'stim_sampling_rate' : sampling_rate}
    return(ret_dict)
    """
    return pd.Series([stim_amps, stim_duration, stim_start_time, stim_end_time, num_sweeps, sampling_rate], 
                     index=['stim_amp_vec', 'stim_duration', 'stim_start_time', 'stim_end_time', 'num_sweeps', 'stim_sampling_rate'])
    """

# %%
to_extract_stim_info
# Out:
#         file_name                                               path  \
# 18   18o22001.abf  data/raw/recordings/Human tissue/Human tissue-...
# 23   18o22020.abf  data/raw/recordings/Human tissue/Human tissue-...
# 30   18o22010.abf  data/raw/recordings/Human tissue/Human tissue-...
# 50   18329033.abf  data/raw/recordings/Human tissue/Human tissue-...
# 53   18329031.abf  data/raw/recordings/Human tissue/Human tissue-...
# 54   18329044.abf  data/raw/recordings/Human tissue/Human tissue-...
# 55   18329043.abf  data/raw/recordings/Human tissue/Human tissue-...
# 58   18329062.abf  data/raw/recordings/Human tissue/Human tissue-...
# 59   18329013.abf  data/raw/recordings/Human tissue/Human tissue-...
# 60   18329014.abf  data/raw/recordings/Human tissue/Human tissue-...
# 62   18329050.abf  data/raw/recordings/Human tissue/Human tissue-...
# 63   18329051.abf  data/raw/recordings/Human tissue/Human tissue-...
# 72   18129009.abf  data/raw/recordings/Human tissue/Human tissue-...
# 77   18129004.abf  data/raw/recordings/Human tissue/Human tissue-...
# 86   18426010.abf  data/raw/recordings/Human tissue/Human tissue-...
# 88   18426000.abf  data/raw/recordings/Human tissue/Human tissue-...
# 90   18426009.abf  data/raw/recordings/Human tissue/Human tissue-...
# 95   18426016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 96   18426017.abf  data/raw/recordings/Human tissue/Human tissue-...
# 102  18320000.abf  data/raw/recordings/Human tissue/Human tissue-...
# 109  18320016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 110  18320019.abf  data/raw/recordings/Human tissue/Human tissue-...
# 112  18320014.abf  data/raw/recordings/Human tissue/Human tissue-...
# 113  18320012.abf  data/raw/recordings/Human tissue/Human tissue-...
# 115  18320030.abf  data/raw/recordings/Human tissue/Human tissue-...
# 116  18320031.abf  data/raw/recordings/Human tissue/Human tissue-...
# 117  18320024.abf  data/raw/recordings/Human tissue/Human tissue-...
# 125  18320005.abf  data/raw/recordings/Human tissue/Human tissue-...
# 129  18320021.abf  data/raw/recordings/Human tissue/Human tissue-...
# 131  18320019.abf  data/raw/recordings/Human tissue/Human tissue-...
# 133  18320014.abf  data/raw/recordings/Human tissue/Human tissue-...
# 137  18320016.abf  data/raw/recordings/Human tissue/Human tissue-...
# 140  18201011.abf  data/raw/recordings/Human tissue/Human tissue-...
# 148  18201029.abf  data/raw/recordings/Human tissue/Human tissue-...
# 149  18201028.abf  data/raw/recordings/Human tissue/Human tissue-...
# 154  18201004.abf  data/raw/recordings/Human tissue/Human tissue-...
# 155  18201005.abf  data/raw/recordings/Human tissue/Human tissue-...
# 160  18201028.abf  data/raw/recordings/Human tissue/Human tissue-...
# 161  18220007.abf  data/raw/recordings/Human tissue/Human tissue-...
# 162  18220008.abf  data/raw/recordings/Human tissue/Human tissue-...
# 169  18220002.abf  data/raw/recordings/Human tissue/Human tissue-...
# 171  18220018.abf  data/raw/recordings/Human tissue/Human tissue-...
# 172  18220019.abf  data/raw/recordings/Human tissue/Human tissue-...
#
#
# 59   [C3; L2/3; RMP -61.5,, C3; L2/3; RMP -61.5, Of...  18329013
# 60                [C3; L2/3; RMP -61.5, Offset -15 mv]  18329014
# 62                          [C10  L2/3; RMP -69.7 mv;]  18329050
# 63   [C10  L2/3; RMP -69.7 mv;, C10  L2/3; RMP -69....  18329051
# 72                           [C3,  L5, RMP: -69.4 mv,]  18129009
# 77                            [C2,  L5, RMP: -71.2 mv]  18129004
# 86                          [Cell 1; RMP -65.3; L2/3,]  18426010
# 88                                  [Cell 1,RMP -64.7]  18426000
# 90   [Cell 1; RMP -65.3; L2/3, Gain, Cell 1; RMP -6...  18426009
# 95   [Cell 2; RMP -64.5; L2/3, Offset -14..8 Gain 5...  18426016
# 96   [Cell 2; RMP -64.5; L2/3, Offset -14..8 Gain 5...  18426017
# 102                            [C1; L2/3; RMP --61.4;]  18320000
# 109                             [C3; L2/3; RMP -66.2;]  18320016
# 110                             [C3; L2/3; RMP -66.2;]  18320019
# 112                              [C2; L2/3; RMP -65.2]  18320014
# 113                              [C2; L2/3; RMP -65.2]  18320012
# 115                              [C5; L2/3; RMP -62.4]  18320030
# 116                              [C5; L2/3; RMP -62.4]  18320031
# 117                              [C4 L2/3; RMP -63.6;]  18320024
# 125     [C1; L2/3; RMP -70.5; Offset 20 mv;1s;-220/40]  18320005
# 129              [C3; L2/3; RMP -71.3; offset -27 mv;]  18320021
# 131              [C3; L2/3; RMP -71.3; offset -27 mv;]  18320019
# 133               [C2; L2/3; RMP -68.1; offset -20 mv]  18320014
# 137  [C2; L2/3; RMP -68.1; offset -20 mv; Gain 20; ...  18320016
# 140                        [C3, RMP -66.5 mv, layer 5]  18201011
# 148                       [C5, RMP -66.9 mv, layer 5,]  18201029
# 149                       [C5, RMP -66.9 mv, layer 5,]  18201028
# 154        [C1, RMP 60.1mV, gain 20, DC 25, every 20s]  18201004
# 155                           [C1, RMP 60.1mV,Ramp 25]  18201005
# 160  [C4, RMP -64.8 mv, layer 5,Gain 20, DC 25, C4,...  18201028
# 161         [C3;  l2/3 ; RMP -63.2 mv; offset -22.5mv]  18220007
# 162         [C3;  l2/3 ; RMP -63.2 mv; offset -22.5mv]  18220008
# 169                             [c2 l2/3 RMP -63.2 mv]  18220002
# 171          [C4;  l2/3 ; RMP -64.9 mv; offset -20 mv]  18220018
# 172          [C4;  l2/3 ; RMP -64.9 mv; offset -20 mv]  18220019

# %%
stim_info = {}
for i, row in to_extract_stim_info.iterrows():
    try:
        abf_info = get_stim_info(row.path, stim_name = 'sweepC')
    except (AttributeError, ValueError, IndexError) as e:
        print(e)
        abf_info = None
    stim_info[row.file_name] = abf_info
    
stim_info_df = pd.DataFrame(stim_info).T
# Out:
# index 5000 is out of bounds for axis 0 with size 3000
# 'ABF' object has no attribute '_stringsIndexed'
# 'ABF' object has no attribute '_stringsIndexed'

# %%
stim_info_dir = Path('./data/processed/meta/stiminfo/')
stim_info_dir.mkdir(exist_ok=True)

# %%
stim_info_df.index.name = 'abf_filename'
stim_info_df.to_csv(stim_info_dir / 'human2018_stiminfo.csv')
